# %%
import itertools
import pandas as df
import random

polymers = ["[*]CC([*])C", "[*]CC([*])CC","[*]CC([*])CCC","[*]CC([*])CC(C)C","[*]CCCCCCCC([*])C","[*]CC([*])O","[*]CC([*])OC(=O)CCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCCCC","[*]CC([*])(C)C#N"]
enzymes = ["PETase", "LCC", "TfH","ThC_Cut1","ThC_Cut2","HiC","FsC","PET2","PET5","Cut190"]

# https://docs.python.org/3/library/itertools.html

pr = itertools.product(polymers, enzymes)
times = range(0, 1000, 24)
xc = [44.47, 34.04, 20.01, 21.64, 31.47, 39.089205, 12.02, 33.35, 37.02, 8.0]
my_list = []

for pol, enz in pr:
    xc_values = xc.copy()
    for time in times:
        xc_values.append(random.randint(2, 5))  # Append a random int between 10 and 20 to xc_values
        xc_value = xc_values[-1]  # Get the last xc value from the list xc_values
        my_list.append({"time/h": time, "polymer": pol, "enzyme": enz, "crystallinity xc": xc_value})
my_list = df.DataFrame(my_list)
print(my_list)
# Out:
#       time/h           polymer  enzyme  crystallinity xc
# 0          0       [*]CC([*])C  PETase                 2
# 1         24       [*]CC([*])C  PETase                 5
# 2         48       [*]CC([*])C  PETase                 3
# 3         72       [*]CC([*])C  PETase                 4
# 4         96       [*]CC([*])C  PETase                 4
# ...      ...               ...     ...               ...
# 4195     888  [*]CC([*])(C)C#N  Cut190                 3
# 4196     912  [*]CC([*])(C)C#N  Cut190                 2
# 4197     936  [*]CC([*])(C)C#N  Cut190                 2
# 4198     960  [*]CC([*])(C)C#N  Cut190                 4
# 4199     984  [*]CC([*])(C)C#N  Cut190                 4
#
# [4200 rows x 4 columns]

# %%
import itertools
import pandas as df
import random

polymers = ["[*]CC([*])C", "[*]CC([*])CC","[*]CC([*])CCC","[*]CC([*])CC(C)C","[*]CCCCCCCC([*])C","[*]CC([*])O","[*]CC([*])OC(=O)CCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCCCC","[*]CC([*])(C)C#N"]
enzymes = ["PETase", "LCC", "TfH","ThC_Cut1","ThC_Cut2","HiC","FsC","PET2","PET5","Cut190"]

# https://docs.python.org/3/library/itertools.html

pr = itertools.product(polymers, enzymes)
times = range(0, 1000, 10)
xc = [44.47, 34.04, 20.01, 21.64, 31.47, 39.089205, 12.02, 33.35, 37.02, 8.0]
my_list = []

for pol, enz in pr:
    xc_value = xc[polymers.index(pol)]  # Get the initial xc value for the corresponding polymer
    for time in times:
        if time != 0:
            xc_value += random.randint(2, 5)  # Increase xc with a random int between 2 and 5
        my_list.append({"time/h": time, "polymer": pol, "enzyme": enz, "crystallinity xc": xc_value})
my_list = df.DataFrame(my_list)
print(my_list)
# Out:
#       time/h           polymer  enzyme  crystallinity xc
# 0          0       [*]CC([*])C  PETase             44.47
# 1         10       [*]CC([*])C  PETase             46.47
# 2         20       [*]CC([*])C  PETase             51.47
# 3         30       [*]CC([*])C  PETase             54.47
# 4         40       [*]CC([*])C  PETase             57.47
# ...      ...               ...     ...               ...
# 9995     950  [*]CC([*])(C)C#N  Cut190            350.00
# 9996     960  [*]CC([*])(C)C#N  Cut190            352.00
# 9997     970  [*]CC([*])(C)C#N  Cut190            356.00
# 9998     980  [*]CC([*])(C)C#N  Cut190            360.00
# 9999     990  [*]CC([*])(C)C#N  Cut190            363.00
#
# [10000 rows x 4 columns]

# %%
print(my_list[0:101])
# Out:
#      time/h      polymer  enzyme  crystallinity xc
# 0         0  [*]CC([*])C  PETase             44.47
# 1        10  [*]CC([*])C  PETase             46.47
# 2        20  [*]CC([*])C  PETase             51.47
# 3        30  [*]CC([*])C  PETase             54.47
# 4        40  [*]CC([*])C  PETase             57.47
# ..      ...          ...     ...               ...
# 96      960  [*]CC([*])C  PETase            377.47
# 97      970  [*]CC([*])C  PETase            379.47
# 98      980  [*]CC([*])C  PETase            383.47
# 99      990  [*]CC([*])C  PETase            388.47
# 100       0  [*]CC([*])C     LCC             44.47
#
# [101 rows x 4 columns]

# %%
import itertools
import pandas as df
import random

polymers = ["[*]CC([*])C", "[*]CC([*])CC","[*]CC([*])CCC","[*]CC([*])CC(C)C","[*]CCCCCCCC([*])C","[*]CC([*])O","[*]CC([*])OC(=O)CCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCC","[*]CC([*])OC(=O)CCCCCCCCCCCCCCCCC","[*]CC([*])(C)C#N"]
enzymes = ["PETase", "LCC", "TfH","ThC_Cut1","ThC_Cut2","HiC","FsC","PET2","PET5","Cut190"]

# https://docs.python.org/3/library/itertools.html

pr = itertools.product(polymers, enzymes)
xc = [44.47, 34.04, 20.01, 21.64, 31.47, 39.089205, 12.02, 33.35, 37.02, 8.0]
my_list = []

for pol, enz in pr:
    xc_value = xc[polymers.index(pol)]  # Get the initial xc value for the corresponding polymer
    for time in range(0, 500, 24):
        if time != 0:
            xc_value += random.uniform(0.5, 2.5)  # Increase xc with a random int between 2 and 5
        my_list.append({"time/h": time, "polymer": pol, "enzyme": enz, "crystallinity xc": xc_value})
my_list = df.DataFrame(my_list)
print(my_list)
# Out:
#       time/h           polymer  enzyme  crystallinity xc
# 0          0       [*]CC([*])C  PETase         44.470000
# 1         24       [*]CC([*])C  PETase         45.907354
# 2         48       [*]CC([*])C  PETase         47.967674
# 3         72       [*]CC([*])C  PETase         48.675508
# 4         96       [*]CC([*])C  PETase         51.172111
# ...      ...               ...     ...               ...
# 2095     384  [*]CC([*])(C)C#N  Cut190         33.490359
# 2096     408  [*]CC([*])(C)C#N  Cut190         35.956161
# 2097     432  [*]CC([*])(C)C#N  Cut190         37.680439
# 2098     456  [*]CC([*])(C)C#N  Cut190         38.265700
# 2099     480  [*]CC([*])(C)C#N  Cut190         40.425898
#
# [2100 rows x 4 columns]

# %%
my_list[0:44]
# Out:
#     time/h      polymer  enzyme  crystallinity xc
# 0        0  [*]CC([*])C  PETase         44.470000
# 1       24  [*]CC([*])C  PETase         45.907354
# 2       48  [*]CC([*])C  PETase         47.967674
# 3       72  [*]CC([*])C  PETase         48.675508
# 4       96  [*]CC([*])C  PETase         51.172111
# 5      120  [*]CC([*])C  PETase         52.456439
# 6      144  [*]CC([*])C  PETase         54.458182
# 7      168  [*]CC([*])C  PETase         56.023492
# 8      192  [*]CC([*])C  PETase         57.332297
# 9      216  [*]CC([*])C  PETase         59.256126
# 10     240  [*]CC([*])C  PETase         60.101169
# 11     264  [*]CC([*])C  PETase         61.831176
# 12     288  [*]CC([*])C  PETase         62.939745
# 13     312  [*]CC([*])C  PETase         64.126690
# 14     336  [*]CC([*])C  PETase         65.103465
# 15     360  [*]CC([*])C  PETase         65.608755
# 16     384  [*]CC([*])C  PETase         66.180250
# 17     408  [*]CC([*])C  PETase         66.949199
# 18     432  [*]CC([*])C  PETase         67.827521
# 19     456  [*]CC([*])C  PETase         69.606008
# 20     480  [*]CC([*])C  PETase         71.359636
# 21       0  [*]CC([*])C     LCC         44.470000
# 22      24  [*]CC([*])C     LCC         46.348713
# 23      48  [*]CC([*])C     LCC         48.624759
# 24      72  [*]CC([*])C     LCC         49.522687
# 25      96  [*]CC([*])C     LCC         50.582302
# 26     120  [*]CC([*])C     LCC         52.094542
# 27     144  [*]CC([*])C     LCC         53.383040
# 28     168  [*]CC([*])C     LCC         54.299672
# 29     192  [*]CC([*])C     LCC         55.727916
# 30     216  [*]CC([*])C     LCC         57.530399
# 31     240  [*]CC([*])C     LCC         59.377521
# 32     264  [*]CC([*])C     LCC         61.472277
# 33     288  [*]CC([*])C     LCC         62.012177
# 34     312  [*]CC([*])C     LCC         64.059317
# 35     336  [*]CC([*])C     LCC         65.612966
# 36     360  [*]CC([*])C     LCC         67.050792
# 37     384  [*]CC([*])C     LCC         68.485996
# 38     408  [*]CC([*])C     LCC         70.410938
# 39     432  [*]CC([*])C     LCC         72.684064
# 40     456  [*]CC([*])C     LCC         73.640932
# 41     480  [*]CC([*])C     LCC         74.251842
# 42       0  [*]CC([*])C     TfH         44.470000
# 43      24  [*]CC([*])C     TfH         45.354478

# %%
my_list[500:600]
# Out:
#      time/h        polymer    enzyme  crystallinity xc
# 500     408  [*]CC([*])CCC  ThC_Cut1         45.466235
# 501     432  [*]CC([*])CCC  ThC_Cut1         47.187683
# 502     456  [*]CC([*])CCC  ThC_Cut1         49.685774
# 503     480  [*]CC([*])CCC  ThC_Cut1         51.337845
# 504       0  [*]CC([*])CCC  ThC_Cut2         20.010000
# ..      ...            ...       ...               ...
# 595     168  [*]CC([*])CCC      PET5         30.166931
# 596     192  [*]CC([*])CCC      PET5         30.869165
# 597     216  [*]CC([*])CCC      PET5         31.393562
# 598     240  [*]CC([*])CCC      PET5         32.645722
# 599     264  [*]CC([*])CCC      PET5         33.607523
#
# [100 rows x 4 columns]

# %%
# Out:
# 'hi'
